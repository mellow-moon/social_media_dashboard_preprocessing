# %% [markdown]
# # Данные
#
# В данных представлена статистика с различными метриками социальных сетей (репосты, лайки, просмотры и т.д.). Используются данные за один месяц (декабрь 2022 года).
#
# Полный датасет можно найти по ссылке: https://www.kaggle.com/datasets/ramjasmaurya/top-1000-social-media-channels.

# %% [markdown]
# # Какие данные представлены?
#
# Используются датасеты со статистикой по трем социальным сетям - Instagram, TikTok, YouTube.
#
# ### Instagram
#
# - Rank - колонка с индексом
# - name - имя блогера
# - instagram name - ник блогера в Instagram
# - Category_1 - категория производимого блогером контента 1
# - Category_2 - категория производимого блогером контента 2
# - followers - количество подписчиков
# - country - в какой стране проживает основная аудитория блогера
# - Eng. (Auth.) - вовлеченность подписчиков (взаимодействия подписчиков с контентом блогера)
# - Eng. (Avg.) - общая вовлеченность (взаимодействия как подписчиков так и не подписчиков)
#
# ### TikTok
#
# - Rank - колонка с индексом
# - Tiktoker name - ник блогера в TikTok
# - Tiktok name - имя блогера
# - followers - количество подписчиков
# - views(avg) - среднее число просмотров
# - likes(avg.) - среднее число лайков
# - comments(avg.) - среднее число комментариев
# - shares(avg.) - среднее число репостов
#
# ### YouTube
#
# - s.no - колонка с индексом
# - Youtube channel - название канала
# - youtuber name - имя блогера
# - Category - категория производимого блогером контента 1
# - Category-2 - категория производимого блогером контента 2
# - Followers - количество подписчиков
# - Country - в какой стране проживает основная аудитория блогера
# - Views (Avg.) - среднее число просмотров
# - Likes (Avg.) - среднее число лайков
# - Comments (Avg.) - среднее число комментариев

# %% [markdown]
# # Задача
#
# Предобработать данные для составления дашборда в Microsoft Power BI. Дашборд должен упрощать поиск блогеров, соответствующих определенным условиям.
#
# ### Instagram
#
# Сортировка по:
#
# - рангу (числу подписчиков)
# - категории контента
# - стране, в которой проживает основная аудитория
#
# ### TikTok
#
# Сортировка по:
#
# - рангу (числу подписчиков)
# - уровню вовлеченности подписчиков
# - уровню привлекательности контента блогера
#
# ### YouTube
#
# Сортировка по:
#
# - рангу (числу подписчиков)
# - категории контента
# - стране, в которой проживает основная аудитория

# %%
# Загрузка нужных библиотек
import re

import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Instagram

# %%
# Загрузка данных
df_inst = pd.read_csv('data/instagram/social media influencers-INSTAGRAM - -DEC 2022.csv')
print(df_inst.shape)
df_inst.head()
# Out:
# (1000, 9)
#    Rank           name     instagram name          Category_1 Category_2  \
# 0     1       leomessi          Leo Messi  Sports with a ball     Family
# 1     2      cristiano  Cristiano Ronaldo  Sports with a ball        NaN
# 2     3       neymarjr              NJ 🇧🇷  Sports with a ball        NaN
# 3     4    kyliejenner            Kylie 🤍             Fashion   Modeling
# 4     5  kendalljenner            Kendall            Modeling    Fashion
#
#   followers        country Eng. (Auth.) Eng. (Avg.)
# 0    409.8M      Argentina        17.8M       23.4M
# 1      523M          India        11.7M       14.7M
# 2    198.9M         Brazil         6.7M        9.5M
# 3    376.3M  United States         2.7M        4.3M
# 4      268M  United States         3.2M          5M

# %% [markdown]
# Переименуем нужные колонки, остальные удалим.

# %%
df_inst = df_inst.drop(columns=['Rank', 'Category_2'])

df_inst = df_inst.rename(columns={'name': 'Ник Instagram',
                                  'instagram name': 'Имя',
                                  'followers': 'Подписчики',
                                  'country': 'Основная аудитория',
                                  'Eng. (Auth.)': 'Вовлеченность подписчиков',
                                  'Eng. (Avg.)': 'Общая вовлеченность',
                                  'Category_1': 'Категория контента'})

df_inst = df_inst[['Ник Instagram', 'Имя', 'Основная аудитория', 'Подписчики', 'Вовлеченность подписчиков', 'Общая вовлеченность', 'Категория контента']]

df_inst
# Out:
#        Ник Instagram                  Имя Основная аудитория Подписчики  \
# 0           leomessi            Leo Messi          Argentina     409.8M
# 1          cristiano    Cristiano Ronaldo              India       523M
# 2           neymarjr                NJ 🇧🇷             Brazil     198.9M
# 3        kyliejenner              Kylie 🤍      United States     376.3M
# 4      kendalljenner              Kendall      United States       268M
# ..               ...                  ...                ...        ...
# 995          thiago6     Thiago Alcantara     United Kingdom      10.4M
# 996  soycintiacossio        Cintia Cossio           Colombia         6M
# 997        feat.dino                   이찬        South Korea       2.7M
# 998       djokernole       Novak Djokovic      United States      11.8M
# 999  ravindra.jadeja  Ravindrasinh jadeja              India       4.8M
#
#     Вовлеченность подписчиков Общая вовлеченность  Категория контента
# 0                       17.8M               23.4M  Sports with a ball
# 1                       11.7M               14.7M  Sports with a ball
# 2                        6.7M                9.5M  Sports with a ball
# 3                        2.7M                4.3M             Fashion
# 4                        3.2M                  5M            Modeling
# ..                        ...                 ...                 ...
# 995                    129.9K              222.7K  Sports with a ball
# 996                    313.4K              390.6K            Modeling
# 997                    716.6K              876.4K           Lifestyle
# 998                    158.6K              197.5K  Sports with a ball
# 999                    388.9K              485.1K           Lifestyle
#
# [1000 rows x 7 columns]

# %% [markdown]
# Посмотрим, есть ли в данных пропуски.

# %%
df_inst.isnull().sum()
# Out:
# Ник Instagram                 0
# Имя                          19
# Основная аудитория            1
# Подписчики                    0
# Вовлеченность подписчиков     0
# Общая вовлеченность           0
# Категория контента           50
# dtype: int64

# %%
df_inst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ник Instagram              1000 non-null   object
#  1   Имя                        981 non-null    object
#  2   Основная аудитория         999 non-null    object
#  3   Подписчики                 1000 non-null   object
#  4   Вовлеченность подписчиков  1000 non-null   object
#  5   Общая вовлеченность        1000 non-null   object
#  6   Категория контента         950 non-null    object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %% [markdown]
# Числовые данные представлены в виде строк, поэтому проведем преобразование к числовому типу данных.

# %%
def str_to_int(str_number):
    '''
    Функция для получения из строки числа.
    Если в строке есть символ 'M', строка преобразуется в число и умножается на миллион.
    Если в строке есть символ 'K', строка преобразуется в число и умножается на тысячу.
    Если нет ни одного из этих символов, то возвращается преобразованная строка.
    '''
    if 'M' in str_number:
        str_number = str_number.replace('M', '')
        str_number = float(str_number) * 1000000

        return str_number
    
    elif 'K' in str_number:
        str_number = str_number.replace('K', '')
        str_number = float(str_number) * 1000

        return str_number

    else:
        str_number = float(str_number)

        return str_number

# %%
df_inst['Подписчики'] = df_inst['Подписчики'].apply(str_to_int)

df_inst['Вовлеченность подписчиков'] = df_inst['Вовлеченность подписчиков'].apply(str_to_int)

df_inst['Общая вовлеченность'] = df_inst['Общая вовлеченность'].apply(str_to_int)

# %% [markdown]
# Сделаем колонку с рангом блогеров в зависимости от количества подписчиков.

# %%
def inst_ranking(sub_count):
    '''
    Функция возвращает ранг в зависимости от переданного числа.
    Больше 100 миллионов - "Мега".
    Больше 30 миллионов и меньше 100 миллионов - "Макро".
    Больше 10 миллионов и меньше 30 миллионов - "Микро".
    Меньше 10 миллионов - "Нано".
    '''
    if sub_count > 100000000:
        return 'Мега (>100M)'
    elif (sub_count > 30000000) and (sub_count < 100000000):
        return 'Макро (>30M) & (<100M)'
    elif (sub_count > 10000000) and (sub_count < 30000000):
        return 'Микро (>10M) & (<30M)'
    else:
        return 'Нано (<10M)'

# %%
df_inst['Ранг'] = df_inst['Подписчики'].apply(inst_ranking)

# %% [markdown]
# Удалим дубликаты и пустые значения.

# %%
df_inst = df_inst.drop_duplicates()
df_inst = df_inst.dropna()
df_inst
# Out:
#        Ник Instagram                  Имя Основная аудитория   Подписчики  \
# 0           leomessi            Leo Messi          Argentina  409800000.0
# 1          cristiano    Cristiano Ronaldo              India  523000000.0
# 2           neymarjr                NJ 🇧🇷             Brazil  198900000.0
# 3        kyliejenner              Kylie 🤍      United States  376300000.0
# 4      kendalljenner              Kendall      United States  268000000.0
# ..               ...                  ...                ...          ...
# 995          thiago6     Thiago Alcantara     United Kingdom   10400000.0
# 996  soycintiacossio        Cintia Cossio           Colombia    6000000.0
# 997        feat.dino                   이찬        South Korea    2700000.0
# 998       djokernole       Novak Djokovic      United States   11800000.0
# 999  ravindra.jadeja  Ravindrasinh jadeja              India    4800000.0
#
#      Вовлеченность подписчиков  Общая вовлеченность  Категория контента  \
# 0                   17800000.0           23400000.0  Sports with a ball
# 1                   11700000.0           14700000.0  Sports with a ball
# 2                    6700000.0            9500000.0  Sports with a ball
# 3                    2700000.0            4300000.0             Fashion
# 4                    3200000.0            5000000.0            Modeling
# ..                         ...                  ...                 ...
# 995                   129900.0             222700.0  Sports with a ball
# 996                   313400.0             390600.0            Modeling
# 997                   716600.0             876400.0           Lifestyle
# 998                   158600.0             197500.0  Sports with a ball
# 999                   388900.0             485100.0           Lifestyle
#
#                       Ранг
# 0             Мега (>100M)
# 1             Мега (>100M)
# 2             Мега (>100M)
# 3             Мега (>100M)
# 4             Мега (>100M)
# ..                     ...
# 995  Микро (>10M) & (<30M)
# 996            Нано (<10M)
# 997            Нано (<10M)
# 998  Микро (>10M) & (<30M)
# 999            Нано (<10M)
#
# [923 rows x 8 columns]

# %% [markdown]
# Каком образом распределились ранги блогеров?

# %%
df_inst['Ранг'].value_counts()
# Out:
# Ранг
# Микро (>10M) & (<30M)     478
# Нано (<10M)               240
# Макро (>30M) & (<100M)    175
# Мега (>100M)               30
# Name: count, dtype: int64

# %% [markdown]
# Переименуем значения колонки со странами аудитории.

# %%
df_inst = df_inst.replace({'Основная аудитория': {'Argentina': 'Аргентина',
                                                  'India': 'Индия',
                                                  'Brazil': 'Бразилия',
                                                  'United States': 'США',
                                                  'France': 'Франция',
                                                  'South Korea': 'Южная Корея',
                                                  'Indonesia': 'Индонезия',
                                                  'Mexico': 'Мексика',
                                                  'Ethiopia': 'Эфиопия',
                                                  'Spain': 'Испания',
                                                  'Turkey': 'Турция',
                                                  'Italy': 'Италия',
                                                  'Morocco': 'Морокко',
                                                  'Poland': 'Польша',
                                                  'China': 'Китай',
                                                  'United Kingdom': 'Великобритания',
                                                  'Iran': 'Иран',
                                                  'Russia': 'Россия',
                                                  'Colombia': 'Колумбия',
                                                  'Australia': 'Австралия',
                                                  'Philippines': 'Филиппины',
                                                  'Yemen': 'Йемен',
                                                  'Egypt': 'Египет',
                                                  'United Arab Emirates': 'ОАЭ',
                                                  'Germany': 'Германия',
                                                  'Thailand': 'Таиланд',
                                                  'Portugal': 'Португалия',
                                                  'Nigeria': 'Нигерия',
                                                  'Iraq': 'Ирак',
                                                  'Algeria': 'Алжир',
                                                  'Albania': 'Албания',
                                                  'Syria': 'Сирия',
                                                  'Japan': 'Япония',
                                                  'Chile': 'Чили'}})

df_inst
# Out:
#        Ник Instagram                  Имя Основная аудитория   Подписчики  \
# 0           leomessi            Leo Messi          Аргентина  409800000.0
# 1          cristiano    Cristiano Ronaldo              Индия  523000000.0
# 2           neymarjr                NJ 🇧🇷           Бразилия  198900000.0
# 3        kyliejenner              Kylie 🤍                США  376300000.0
# 4      kendalljenner              Kendall                США  268000000.0
# ..               ...                  ...                ...          ...
# 995          thiago6     Thiago Alcantara     Великобритания   10400000.0
# 996  soycintiacossio        Cintia Cossio           Колумбия    6000000.0
# 997        feat.dino                   이찬        Южная Корея    2700000.0
# 998       djokernole       Novak Djokovic                США   11800000.0
# 999  ravindra.jadeja  Ravindrasinh jadeja              Индия    4800000.0
#
#      Вовлеченность подписчиков  Общая вовлеченность  Категория контента  \
# 0                   17800000.0           23400000.0  Sports with a ball
# 1                   11700000.0           14700000.0  Sports with a ball
# 2                    6700000.0            9500000.0  Sports with a ball
# 3                    2700000.0            4300000.0             Fashion
# 4                    3200000.0            5000000.0            Modeling
# ..                         ...                  ...                 ...
# 995                   129900.0             222700.0  Sports with a ball
# 996                   313400.0             390600.0            Modeling
# 997                   716600.0             876400.0           Lifestyle
# 998                   158600.0             197500.0  Sports with a ball
# 999                   388900.0             485100.0           Lifestyle
#
#                       Ранг
# 0             Мега (>100M)
# 1             Мега (>100M)
# 2             Мега (>100M)
# 3             Мега (>100M)
# 4             Мега (>100M)
# ..                     ...
# 995  Микро (>10M) & (<30M)
# 996            Нано (<10M)
# 997            Нано (<10M)
# 998  Микро (>10M) & (<30M)
# 999            Нано (<10M)
#
# [923 rows x 8 columns]

# %% [markdown]
# Переименуем значения колонки с категориями контента.

# %%
df_inst = df_inst.replace({'Категория контента': {'Sports with a ball': 'Виды спорта с мячом',
                                                  'Fashion': 'Мода',
                                                  'Modeling': 'Модель',
                                                  'Music': 'Музыка',
                                                  'Photography': 'Фотография',
                                                  'Lifestyle': 'Стиль жизни',
                                                  'Fitness & Gym': 'Фитнес',
                                                  'Art/Artists': 'Искусство/Художники',
                                                  'Cinema & Actors/actresses': 'Кино и Актеры/Актрисы',
                                                  'Finance & Economics': 'Финансы и Экономика',
                                                  'Science': 'Наука',
                                                  'Shows': 'Шоу',
                                                  'Beauty': 'Красота',
                                                  'Humor & Fun & Happiness': 'Юмор/Шутки',
                                                  'Family': 'Семья',
                                                  'Racing Sports': 'Гоночные виды спорта',
                                                  'Clothing & Outfits': 'Одежда',
                                                  'Computers & Gadgets': 'Компьютеры и Гаджеты',
                                                  'Food & Cooking': 'Еда',
                                                  'Nature & landscapes': 'Природа',
                                                  'Literature & Journalism': 'Литература и Журналистика',
                                                  'Business & Careers': 'Бизнес и Карьера',
                                                  'Cars & Motorbikes': 'Автомобили и Мотоциклы',
                                                  'Luxury': 'Предметы роскоши',
                                                  'Gaming': 'Компьютерные игры',
                                                  'Machinery & Technologies': 'Машины и технологии',
                                                  'Adult content': 'Контент для взрослых',
                                                  'Animals': 'Животные',
                                                  'Education': 'Образование',
                                                  'Water sports': 'Водные виды спорта',
                                                  'Winter sports': 'Зимние виды спорта',
                                                  'Travel': 'Путешествия'}})

df_inst
# Out:
#        Ник Instagram                  Имя Основная аудитория   Подписчики  \
# 0           leomessi            Leo Messi          Аргентина  409800000.0
# 1          cristiano    Cristiano Ronaldo              Индия  523000000.0
# 2           neymarjr                NJ 🇧🇷           Бразилия  198900000.0
# 3        kyliejenner              Kylie 🤍                США  376300000.0
# 4      kendalljenner              Kendall                США  268000000.0
# ..               ...                  ...                ...          ...
# 995          thiago6     Thiago Alcantara     Великобритания   10400000.0
# 996  soycintiacossio        Cintia Cossio           Колумбия    6000000.0
# 997        feat.dino                   이찬        Южная Корея    2700000.0
# 998       djokernole       Novak Djokovic                США   11800000.0
# 999  ravindra.jadeja  Ravindrasinh jadeja              Индия    4800000.0
#
#      Вовлеченность подписчиков  Общая вовлеченность   Категория контента  \
# 0                   17800000.0           23400000.0  Виды спорта с мячом
# 1                   11700000.0           14700000.0  Виды спорта с мячом
# 2                    6700000.0            9500000.0  Виды спорта с мячом
# 3                    2700000.0            4300000.0                 Мода
# 4                    3200000.0            5000000.0               Модель
# ..                         ...                  ...                  ...
# 995                   129900.0             222700.0  Виды спорта с мячом
# 996                   313400.0             390600.0               Модель
# 997                   716600.0             876400.0          Стиль жизни
# 998                   158600.0             197500.0  Виды спорта с мячом
# 999                   388900.0             485100.0          Стиль жизни
#
#                       Ранг
# 0             Мега (>100M)
# 1             Мега (>100M)
# 2             Мега (>100M)
# 3             Мега (>100M)
# 4             Мега (>100M)
# ..                     ...
# 995  Микро (>10M) & (<30M)
# 996            Нано (<10M)
# 997            Нано (<10M)
# 998  Микро (>10M) & (<30M)
# 999            Нано (<10M)
#
# [923 rows x 8 columns]

# %%
# Сохранение датасета
# df_inst.to_excel('data/df_inst.xlsx', index=False)

# %% [markdown]
# # 2. TikTok

# %%
# Загрузка данных
df_tiktok = pd.read_csv('data/tiktok/social media influencers-TIKTOK - ---DEC 2022.csv')
print(df_tiktok.shape)
df_tiktok.head()
# Out:
# (1000, 8)
#    Rank Tiktoker name Tiktok name followers views(avg) likes(avg.)  \
# 0     1       mrbeast     MrBeast     60.3M      29.2M        3.5M
# 1     2        karolg     Karol G     42.4M      23.7M        3.4M
# 2     3         yzn47  يزن الأسمر      8.9M      48.9M      998.4K
# 3     4    centralcee  CentralCee      4.4M      19.8M        3.6M
# 4     5      adinross        adin      6.1M      21.1M        3.3M
#
#   comments(avg.) shares(avg.)
# 0          30.8K         7.2K
# 1          21.7K        25.7K
# 2          16.3K        60.9K
# 3          23.3K        24.2K
# 4          17.5K        25.3K

# %% [markdown]
# Переименуем нужные колонки, остальные удалим.

# %%
df_tiktok = df_tiktok.drop(columns=['Rank'])

df_tiktok = df_tiktok.rename(columns={'Tiktoker name': 'Ник TikTok',
                                      'Tiktok name': 'Имя',
                                      'followers': 'Подписчики',
                                      'views(avg)': 'Просмотры',
                                      'likes(avg.)': 'Лайки',
                                      'comments(avg.)': 'Комментарии',
                                      'shares(avg.)': 'Репосты'})

df_tiktok
# Out:
#       Ник TikTok                             Имя Подписчики Просмотры   Лайки  \
# 0        mrbeast                         MrBeast      60.3M     29.2M    3.5M
# 1         karolg                         Karol G      42.4M     23.7M    3.4M
# 2          yzn47                      يزن الأسمر       8.9M     48.9M  998.4K
# 3     centralcee                      CentralCee       4.4M     19.8M    3.6M
# 4       adinross                            adin       6.1M     21.1M    3.3M
# ..           ...                             ...        ...       ...     ...
# 995  jiembasands                    Jiemba Sands       4.9M      3.4M  247.4K
# 996   crissa_ace                  Crissa Jackson      14.9M      1.6M  141.7K
# 997     ichadude                   Alyssa & Dude     468.8K      2.3M   85.5K
# 998    kanebrown                      Kane Brown       5.2M      1.7M   96.7K
# 999     nnennab_  Nnenna B | NYC Creator & Actor     149.1K    606.2K   79.5K
#
#     Комментарии Репосты
# 0         30.8K    7.2K
# 1         21.7K   25.7K
# 2         16.3K   60.9K
# 3         23.3K   24.2K
# 4         17.5K   25.3K
# ..          ...     ...
# 995         207     264
# 996        1.2K     580
# 997         997      1K
# 998        1.3K    1.2K
# 999        2.1K    6.1K
#
# [1000 rows x 7 columns]

# %% [markdown]
# Посмотрим, есть ли в данных пропуски.

# %%
df_tiktok.isnull().sum()
# Out:
# Ник TikTok     0
# Имя            0
# Подписчики     0
# Просмотры      0
# Лайки          0
# Комментарии    0
# Репосты        0
# dtype: int64

# %%
df_tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ник TikTok   1000 non-null   object
#  1   Имя          1000 non-null   object
#  2   Подписчики   1000 non-null   object
#  3   Просмотры    1000 non-null   object
#  4   Лайки        1000 non-null   object
#  5   Комментарии  1000 non-null   object
#  6   Репосты      1000 non-null   object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %% [markdown]
# Числовые данные представлены в виде строк, поэтому проведем преобразование к числовому типу данных.

# %%
df_tiktok['Подписчики'] = df_tiktok['Подписчики'].apply(str_to_int)

df_tiktok['Просмотры'] = df_tiktok['Просмотры'].apply(str_to_int)

df_tiktok['Лайки'] = df_tiktok['Лайки'].apply(str_to_int)

df_tiktok['Комментарии'] = df_tiktok['Комментарии'].apply(str_to_int)

df_tiktok['Репосты'] = df_tiktok['Репосты'].apply(str_to_int)

# %% [markdown]
# Сделаем колонку с рангом блогеров в зависимости от количества подписчиков.

# %%
def tiktok_ranking(sub_count):
    '''
    Функция возвращает ранг в зависимости от переданного числа.
    Больше 35 миллионов - "Мега".
    Больше 10 миллионов и меньше 35 миллионов - "Макро".
    Больше 3 миллионов и меньше 10 миллионов - "Микро".
    Меньше 3 миллионов - "Нано".
    '''
    if sub_count > 35000000:
        return 'Мега (>35M)'
    elif (sub_count > 10000000) and (sub_count < 35000000):
        return 'Макро (>10M) & (<35M)'
    elif (sub_count > 3000000) and (sub_count < 10000000):
        return 'Микро (>3M) & (<10M)'
    else:
        return 'Нано (<3M)'

# %%
df_tiktok['Ранг'] = df_tiktok['Подписчики'].apply(tiktok_ranking)

# %% [markdown]
# Удалим дубликаты и пустые значения.

# %%
df_tiktok = df_tiktok.drop_duplicates()
df_tiktok = df_tiktok.dropna()
df_tiktok
# Out:
#       Ник TikTok                             Имя  Подписчики   Просмотры  \
# 0        mrbeast                         MrBeast  60300000.0  29200000.0
# 1         karolg                         Karol G  42400000.0  23700000.0
# 2          yzn47                      يزن الأسمر   8900000.0  48900000.0
# 3     centralcee                      CentralCee   4400000.0  19800000.0
# 4       adinross                            adin   6100000.0  21100000.0
# ..           ...                             ...         ...         ...
# 995  jiembasands                    Jiemba Sands   4900000.0   3400000.0
# 996   crissa_ace                  Crissa Jackson  14900000.0   1600000.0
# 997     ichadude                   Alyssa & Dude    468800.0   2300000.0
# 998    kanebrown                      Kane Brown   5200000.0   1700000.0
# 999     nnennab_  Nnenna B | NYC Creator & Actor    149100.0    606200.0
#
#          Лайки  Комментарии  Репосты                   Ранг
# 0    3500000.0      30800.0   7200.0            Мега (>35M)
# 1    3400000.0      21700.0  25700.0            Мега (>35M)
# 2     998400.0      16300.0  60900.0   Микро (>3M) & (<10M)
# 3    3600000.0      23300.0  24200.0   Микро (>3M) & (<10M)
# 4    3300000.0      17500.0  25300.0   Микро (>3M) & (<10M)
# ..         ...          ...      ...                    ...
# 995   247400.0        207.0    264.0   Микро (>3M) & (<10M)
# 996   141700.0       1200.0    580.0  Макро (>10M) & (<35M)
# 997    85500.0        997.0   1000.0             Нано (<3M)
# 998    96700.0       1300.0   1200.0   Микро (>3M) & (<10M)
# 999    79500.0       2100.0   6100.0             Нано (<3M)
#
# [999 rows x 8 columns]

# %% [markdown]
# Каком образом распределились ранги блогеров?

# %%
df_tiktok['Ранг'].value_counts()
# Out:
# Ранг
# Микро (>3M) & (<10M)     386
# Нано (<3M)               383
# Макро (>10M) & (<35M)    198
# Мега (>35M)               32
# Name: count, dtype: int64

# %% [markdown]
# Сделаем новую колонку с метрикой "Привлекательность", запишем туда отношение количества лайков к количеству подписчиков.

# %%
df_tiktok['Привлекательность'] = round((df_tiktok['Лайки'] / df_tiktok['Подписчики']) * 100)
df_tiktok
# Out:
#       Ник TikTok                             Имя  Подписчики   Просмотры  \
# 0        mrbeast                         MrBeast  60300000.0  29200000.0
# 1         karolg                         Karol G  42400000.0  23700000.0
# 2          yzn47                      يزن الأسمر   8900000.0  48900000.0
# 3     centralcee                      CentralCee   4400000.0  19800000.0
# 4       adinross                            adin   6100000.0  21100000.0
# ..           ...                             ...         ...         ...
# 995  jiembasands                    Jiemba Sands   4900000.0   3400000.0
# 996   crissa_ace                  Crissa Jackson  14900000.0   1600000.0
# 997     ichadude                   Alyssa & Dude    468800.0   2300000.0
# 998    kanebrown                      Kane Brown   5200000.0   1700000.0
# 999     nnennab_  Nnenna B | NYC Creator & Actor    149100.0    606200.0
#
#          Лайки  Комментарии  Репосты                   Ранг  Привлекательность
# 0    3500000.0      30800.0   7200.0            Мега (>35M)                6.0
# 1    3400000.0      21700.0  25700.0            Мега (>35M)                8.0
# 2     998400.0      16300.0  60900.0   Микро (>3M) & (<10M)               11.0
# 3    3600000.0      23300.0  24200.0   Микро (>3M) & (<10M)               82.0
# 4    3300000.0      17500.0  25300.0   Микро (>3M) & (<10M)               54.0
# ..         ...          ...      ...                    ...                ...
# 995   247400.0        207.0    264.0   Микро (>3M) & (<10M)                5.0
# 996   141700.0       1200.0    580.0  Макро (>10M) & (<35M)                1.0
# 997    85500.0        997.0   1000.0             Нано (<3M)               18.0
# 998    96700.0       1300.0   1200.0   Микро (>3M) & (<10M)                2.0
# 999    79500.0       2100.0   6100.0             Нано (<3M)               53.0
#
# [999 rows x 9 columns]

# %% [markdown]
# Сделаем распределение блогеров по уровню привлекательности.

# %%
def tiktok_attraction_level(attraction):
    '''
    Функция возвращает уровень привлекательности в зависимости от переданного значения.
    Больше или равно 150 - "Высокий".
    Больше или равно 50 и меньше 150 - "Средний".
    Меньше 50 - "Низкий".
    '''
    if attraction >= 150:
        return 'Высокий'
    elif (attraction >= 50) and (attraction < 150):
        return 'Средний'
    else:
        return 'Низкий'

# %%
df_tiktok['Уровень привлекательности'] = df_tiktok['Привлекательность'].apply(tiktok_attraction_level)

# %% [markdown]
# Сделаем новую колонку с метрикой "Вовлеченность", запишем туда сумму лайков, комментариев и репостов.

# %%
df_tiktok['Вовлеченность'] = df_tiktok['Лайки'] + df_tiktok['Комментарии'] + df_tiktok['Репосты']
df_tiktok
# Out:
#       Ник TikTok                             Имя  Подписчики   Просмотры  \
# 0        mrbeast                         MrBeast  60300000.0  29200000.0
# 1         karolg                         Karol G  42400000.0  23700000.0
# 2          yzn47                      يزن الأسمر   8900000.0  48900000.0
# 3     centralcee                      CentralCee   4400000.0  19800000.0
# 4       adinross                            adin   6100000.0  21100000.0
# ..           ...                             ...         ...         ...
# 995  jiembasands                    Jiemba Sands   4900000.0   3400000.0
# 996   crissa_ace                  Crissa Jackson  14900000.0   1600000.0
# 997     ichadude                   Alyssa & Dude    468800.0   2300000.0
# 998    kanebrown                      Kane Brown   5200000.0   1700000.0
# 999     nnennab_  Nnenna B | NYC Creator & Actor    149100.0    606200.0
#
#          Лайки  Комментарии  Репосты                   Ранг  \
# 0    3500000.0      30800.0   7200.0            Мега (>35M)
# 1    3400000.0      21700.0  25700.0            Мега (>35M)
# 2     998400.0      16300.0  60900.0   Микро (>3M) & (<10M)
# 3    3600000.0      23300.0  24200.0   Микро (>3M) & (<10M)
# 4    3300000.0      17500.0  25300.0   Микро (>3M) & (<10M)
# ..         ...          ...      ...                    ...
# 995   247400.0        207.0    264.0   Микро (>3M) & (<10M)
# 996   141700.0       1200.0    580.0  Макро (>10M) & (<35M)
# 997    85500.0        997.0   1000.0             Нано (<3M)
# 998    96700.0       1300.0   1200.0   Микро (>3M) & (<10M)
# 999    79500.0       2100.0   6100.0             Нано (<3M)
#
#      Привлекательность Уровень привлекательности  Вовлеченность
# 0                  6.0                    Низкий      3538000.0
# 1                  8.0                    Низкий      3447400.0
# 2                 11.0                    Низкий      1075600.0
# 3                 82.0                   Средний      3647500.0
# 4                 54.0                   Средний      3342800.0
# ..                 ...                       ...            ...
# 995                5.0                    Низкий       247871.0
# 996                1.0                    Низкий       143480.0
# 997               18.0                    Низкий        87497.0
# 998                2.0                    Низкий        99200.0
# 999               53.0                   Средний        87700.0
#
# [999 rows x 11 columns]

# %% [markdown]
# Сделаем распределение блогеров по уровню вовлеченности.

# %%
def tiktok_involvement_level(involvement):
    '''
    Функция возвращает уровень вовлеченности в зависимости от переданного значения.
    Больше или равно 1.5 млн. - "Высокий".
    Больше или равно 200 тыс. и меньше 1.5 млн. - "Средний".
    Меньше 200 тыс. - "Низкий".
    '''
    if involvement >= 1500000:
        return 'Высокий'
    elif (involvement >= 200000) and (involvement < 1500000):
        return 'Средний'
    else:
        return 'Низкий'

# %%
df_tiktok['Уровень вовлеченности'] = df_tiktok['Вовлеченность'].apply(tiktok_involvement_level)

# %% [markdown]
# Удалим колонки с числовыми значениями привлекательности и вовлеченности, оставим только уровни.

# %%
df_tiktok = df_tiktok.drop(columns=['Привлекательность', 'Вовлеченность'])
df_tiktok
# Out:
#       Ник TikTok                             Имя  Подписчики   Просмотры  \
# 0        mrbeast                         MrBeast  60300000.0  29200000.0
# 1         karolg                         Karol G  42400000.0  23700000.0
# 2          yzn47                      يزن الأسمر   8900000.0  48900000.0
# 3     centralcee                      CentralCee   4400000.0  19800000.0
# 4       adinross                            adin   6100000.0  21100000.0
# ..           ...                             ...         ...         ...
# 995  jiembasands                    Jiemba Sands   4900000.0   3400000.0
# 996   crissa_ace                  Crissa Jackson  14900000.0   1600000.0
# 997     ichadude                   Alyssa & Dude    468800.0   2300000.0
# 998    kanebrown                      Kane Brown   5200000.0   1700000.0
# 999     nnennab_  Nnenna B | NYC Creator & Actor    149100.0    606200.0
#
#          Лайки  Комментарии  Репосты                   Ранг  \
# 0    3500000.0      30800.0   7200.0            Мега (>35M)
# 1    3400000.0      21700.0  25700.0            Мега (>35M)
# 2     998400.0      16300.0  60900.0   Микро (>3M) & (<10M)
# 3    3600000.0      23300.0  24200.0   Микро (>3M) & (<10M)
# 4    3300000.0      17500.0  25300.0   Микро (>3M) & (<10M)
# ..         ...          ...      ...                    ...
# 995   247400.0        207.0    264.0   Микро (>3M) & (<10M)
# 996   141700.0       1200.0    580.0  Макро (>10M) & (<35M)
# 997    85500.0        997.0   1000.0             Нано (<3M)
# 998    96700.0       1300.0   1200.0   Микро (>3M) & (<10M)
# 999    79500.0       2100.0   6100.0             Нано (<3M)
#
#     Уровень привлекательности Уровень вовлеченности
# 0                      Низкий               Высокий
# 1                      Низкий               Высокий
# 2                      Низкий               Средний
# 3                     Средний               Высокий
# 4                     Средний               Высокий
# ..                        ...                   ...
# 995                    Низкий               Средний
# 996                    Низкий                Низкий
# 997                    Низкий                Низкий
# 998                    Низкий                Низкий
# 999                   Средний                Низкий
#
# [999 rows x 10 columns]

# %%
# Сохранение датасета
# df_tiktok.to_excel('data/df_tiktok.xlsx', index=False)

# %% [markdown]
# # 3. YouTube

# %%
# Загрузка данных
df_youtube = pd.read_csv('data/youtube/social media influencers-YOUTUBE - --DEC 2022.csv')
print(df_youtube.shape)
df_youtube.head()
# Out:
# (1003, 10)
#    s.no Youtube channel               youtuber name       Category Followers  \
# 0     1         tseries                    T-Series  Music & Dance    229.5M
# 1     2        setindia                   SET India            NaN    147.2M
# 2     3       checkgate  Cocomelon - Nursery Rhymes      Education    146.6M
# 3     4         MrBeast                     MrBeast    Video games      117M
# 4     5       PewDiePie                   PewDiePie      Animation    111.6M
#
#          Country \nViews (Avg.) Likes (Avg.) Comments (Avg.) Category-2
# 0          India         103.8K         2.8K             158        NaN
# 1          India              0            0               0        NaN
# 2            NaN           9.5M        48.3K               0        NaN
# 3  United States          68.5M         2.9M           99.9K      Humor
# 4  United States           1.4M       110.7K            7.8K        NaN

# %% [markdown]
# Переименуем нужные колонки, остальные удалим.

# %%
df_youtube = df_youtube.drop(columns=['s.no', 'Category-2'])

df_youtube = df_youtube.rename(columns={'youtuber name': 'Название канала',
                                        'Youtube channel': 'Ник YouTube',
                                        'Country': 'Основная аудитория',
                                        'Followers': 'Подписчики',
                                        '\nViews (Avg.)': 'Просмотры',
                                        'Likes (Avg.)': 'Лайки',
                                        'Comments (Avg.)': 'Комментарии',
                                        'Category': 'Категория контента'})

df_youtube = df_youtube[['Название канала', 'Ник YouTube', 'Основная аудитория', 'Подписчики', 'Просмотры', 'Лайки', 'Комментарии', 'Категория контента']]

df_youtube
# Out:
#                  Название канала                Ник YouTube  \
# 0                       T-Series                    tseries
# 1                      SET India                   setindia
# 2     Cocomelon - Nursery Rhymes                  checkgate
# 3                        MrBeast                    MrBeast
# 4                      PewDiePie                  PewDiePie
# ...                          ...                        ...
# 998              Classic Mr Bean              ClassicMrBean
# 999           Anupam Movie Songs         Anupam Movie Songs
# 1000                 Anand Audio                 AnandAudio
# 1001                    Wylsacom                   Wylsacom
# 1002   Eagle Home Entertainments  Eagle Home Entertainments
#
#      Основная аудитория Подписчики Просмотры   Лайки Комментарии  \
# 0                 India     229.5M    103.8K    2.8K         158
# 1                 India     147.2M         0       0           0
# 2                   NaN     146.6M      9.5M   48.3K           0
# 3         United States       117M     68.5M    2.9M       99.9K
# 4         United States     111.6M      1.4M  110.7K        7.8K
# ...                 ...        ...       ...     ...         ...
# 998               India      10.1M     48.3K     624          23
# 999          Bangladesh      10.1M     41.2K     315          18
# 1000              India      10.3M    175.5K    2.2K         109
# 1001             Russia      10.3M    291.7K     13K         950
# 1002              India      10.2M       724       3           0
#
#         Категория контента
# 0            Music & Dance
# 1                      NaN
# 2                Education
# 3              Video games
# 4                Animation
# ...                    ...
# 998                    NaN
# 999          Music & Dance
# 1000                   NaN
# 1001  Science & Technology
# 1002                   NaN
#
# [1003 rows x 8 columns]

# %% [markdown]
# Посмотрим, есть ли в данных пропуски.

# %%
df_youtube.isnull().sum()
# Out:
# Название канала         0
# Ник YouTube             0
# Основная аудитория    177
# Подписчики              0
# Просмотры               0
# Лайки                   0
# Комментарии             0
# Категория контента    297
# dtype: int64

# %%
df_youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Название канала     1003 non-null   object
#  1   Ник YouTube         1003 non-null   object
#  2   Основная аудитория  826 non-null    object
#  3   Подписчики          1003 non-null   object
#  4   Просмотры           1003 non-null   object
#  5   Лайки               1003 non-null   object
#  6   Комментарии         1003 non-null   object
#  7   Категория контента  706 non-null    object
# dtypes: object(8)
# memory usage: 62.8+ KB

# %% [markdown]
# Числовые данные представлены в виде строк, поэтому проведем преобразование к числовому типу данных.

# %%
df_youtube['Подписчики'] = df_youtube['Подписчики'] .apply(str_to_int)

df_youtube['Просмотры'] = df_youtube['Просмотры'].apply(str_to_int)

df_youtube['Лайки'] = df_youtube['Лайки'].apply(str_to_int)

df_youtube['Комментарии'] = df_youtube['Комментарии'].apply(str_to_int)

# %% [markdown]
# Сделаем колонку с рангом блогеров в зависимости от количества подписчиков.

# %%
def youtube_ranking(sub_count):
    '''
    Функция возвращает ранг в зависимости от переданного числа.
    Больше 50 миллионов - "Мега".
    Больше 30 миллионов и меньше 50 миллионов - "Макро".
    Больше 15 миллионов и меньше 30 миллионов - "Микро".
    Меньше 15 миллионов - "Нано".
    '''
    if sub_count > 50000000:
        return 'Мега (>50M)'
    elif (sub_count > 30000000) and (sub_count < 50000000):
        return 'Макро (>30M) & (<50M)'
    elif (sub_count > 15000000) and (sub_count < 30000000):
        return 'Микро (>15M) & (<30M)'
    else:
        return 'Нано (<15M)'

# %%
df_youtube['Ранг'] = df_youtube['Подписчики'].apply(youtube_ranking)

# %% [markdown]
# Удалим дубликаты и пустые значения.

# %%
df_youtube = df_youtube.drop_duplicates()
df_youtube = df_youtube.dropna()
df_youtube
# Out:
#             Название канала             Ник YouTube Основная аудитория  \
# 0                  T-Series                 tseries              India
# 3                   MrBeast                 MrBeast      United States
# 4                 PewDiePie               PewDiePie      United States
# 7                       WWE            WWEFanNation      United States
# 9         Zee Music Company         zeemusiccompany              India
# ..                      ...                     ...                ...
# 984          Roshan Zindagi          Roshan Zindagi              India
# 989    Sab Kuchh Sekho Jano       Sabkuchhsikhojano              India
# 991                Fox News          FoxNewsChannel      United States
# 992  Santa Fe Klan Official  Santa Fe Klan Official             Mexico
# 999      Anupam Movie Songs      Anupam Movie Songs         Bangladesh
#
#       Подписчики   Просмотры      Лайки  Комментарии Категория контента  \
# 0    229500000.0    103800.0     2800.0        158.0      Music & Dance
# 3    117000000.0  68500000.0  2900000.0      99900.0        Video games
# 4    111600000.0   1400000.0   110700.0       7800.0          Animation
# 7     91800000.0    144900.0     5100.0        207.0        Video games
# 9     89700000.0     89600.0     2400.0         91.0      Music & Dance
# ..           ...         ...        ...          ...                ...
# 984   10200000.0     21200.0      652.0         15.0          Education
# 989   10100000.0     11800.0     1200.0         72.0    News & Politics
# 991   10100000.0     98400.0     4000.0        884.0    News & Politics
# 992   10100000.0         0.0        0.0          0.0      Music & Dance
# 999   10100000.0     41200.0      315.0         18.0      Music & Dance
#
#             Ранг
# 0    Мега (>50M)
# 3    Мега (>50M)
# 4    Мега (>50M)
# 7    Мега (>50M)
# 9    Мега (>50M)
# ..           ...
# 984  Нано (<15M)
# 989  Нано (<15M)
# 991  Нано (<15M)
# 992  Нано (<15M)
# 999  Нано (<15M)
#
# [578 rows x 9 columns]

# %% [markdown]
# Каком образом распределились ранги блогеров?

# %%
df_youtube['Ранг'].value_counts()
# Out:
# Ранг
# Нано (<15M)              321
# Микро (>15M) & (<30M)    199
# Макро (>30M) & (<50M)     38
# Мега (>50M)               20
# Name: count, dtype: int64

# %% [markdown]
# Переименуем значения колонки со странами аудитории.

# %%
df_youtube = df_youtube.replace({'Основная аудитория': {'India': 'Индия',
                                                        'United States': 'США',
                                                        'Brazil': 'Бразилия',
                                                        'Mexico': 'Мексика',
                                                        'Russia': 'Россия',
                                                        'Colombia': 'Колумбия',
                                                        'France': 'Франция',
                                                        'Indonesia': 'Индонезия',
                                                        'Iraq': 'Ирак',
                                                        'Philippines': 'Филиппины',
                                                        'Turkey': 'Турция',
                                                        'Thailand': 'Таиланд',
                                                        'Argentina': 'Аргентина',
                                                        'Saudi Arabia': 'Саудовская Аравия',
                                                        'United Kingdom': 'Великобритания',
                                                        'Spain': 'Испания',
                                                        'Bangladesh': 'Бангладеш',
                                                        'Pakistan': 'Пакистан',
                                                        'Jordan': 'Иордания',
                                                        'Peru': 'Перу',
                                                        'Algeria': 'Алжир',
                                                        'Japan': 'Япония',
                                                        'Morocco': 'Марокко',
                                                        'Somalia': 'Сомали'}})

df_youtube
# Out:
#             Название канала             Ник YouTube Основная аудитория  \
# 0                  T-Series                 tseries              Индия
# 3                   MrBeast                 MrBeast                США
# 4                 PewDiePie               PewDiePie                США
# 7                       WWE            WWEFanNation                США
# 9         Zee Music Company         zeemusiccompany              Индия
# ..                      ...                     ...                ...
# 984          Roshan Zindagi          Roshan Zindagi              Индия
# 989    Sab Kuchh Sekho Jano       Sabkuchhsikhojano              Индия
# 991                Fox News          FoxNewsChannel                США
# 992  Santa Fe Klan Official  Santa Fe Klan Official            Мексика
# 999      Anupam Movie Songs      Anupam Movie Songs          Бангладеш
#
#       Подписчики   Просмотры      Лайки  Комментарии Категория контента  \
# 0    229500000.0    103800.0     2800.0        158.0      Music & Dance
# 3    117000000.0  68500000.0  2900000.0      99900.0        Video games
# 4    111600000.0   1400000.0   110700.0       7800.0          Animation
# 7     91800000.0    144900.0     5100.0        207.0        Video games
# 9     89700000.0     89600.0     2400.0         91.0      Music & Dance
# ..           ...         ...        ...          ...                ...
# 984   10200000.0     21200.0      652.0         15.0          Education
# 989   10100000.0     11800.0     1200.0         72.0    News & Politics
# 991   10100000.0     98400.0     4000.0        884.0    News & Politics
# 992   10100000.0         0.0        0.0          0.0      Music & Dance
# 999   10100000.0     41200.0      315.0         18.0      Music & Dance
#
#             Ранг
# 0    Мега (>50M)
# 3    Мега (>50M)
# 4    Мега (>50M)
# 7    Мега (>50M)
# 9    Мега (>50M)
# ..           ...
# 984  Нано (<15M)
# 989  Нано (<15M)
# 991  Нано (<15M)
# 992  Нано (<15M)
# 999  Нано (<15M)
#
# [578 rows x 9 columns]

# %% [markdown]
# Переименуем значения колонки с категориями контента.

# %%
df_youtube = df_youtube.replace({'Категория контента': {'Music & Dance': 'Музыка и Танцы',
                                                        'Video games': 'Компьютерные игры',
                                                        'Animation': 'Анимация',
                                                        'Movies': 'Кино',
                                                        'News & Politics': 'Новости и Политика',
                                                        'Daily vlogs': 'Ежедневный влог',
                                                        'Humor': 'Юмор',
                                                        'Fitness': 'Фитнес',
                                                        'Food & Drinks': 'Еда и Напитки',
                                                        'Beauty': 'Красота',
                                                        'DIY & Life Hacks': 'DIY и Лайфхаки',
                                                        'Science & Technology': 'Наука и Технологии',
                                                        'Sports': 'Спорт',
                                                        'Education': 'Образование',
                                                        'Toys': 'Игрушки',
                                                        'Health & Self Help': 'Здоровье',
                                                        'Animals & Pets': 'Животные',
                                                        'ASMR': 'ASMR',
                                                        'Design/art': 'Дизайн/Рисование',
                                                        'Fashion': 'Мода',
                                                        'Travel': 'Путешествия'}})

df_youtube
# Out:
#             Название канала             Ник YouTube Основная аудитория  \
# 0                  T-Series                 tseries              Индия
# 3                   MrBeast                 MrBeast                США
# 4                 PewDiePie               PewDiePie                США
# 7                       WWE            WWEFanNation                США
# 9         Zee Music Company         zeemusiccompany              Индия
# ..                      ...                     ...                ...
# 984          Roshan Zindagi          Roshan Zindagi              Индия
# 989    Sab Kuchh Sekho Jano       Sabkuchhsikhojano              Индия
# 991                Fox News          FoxNewsChannel                США
# 992  Santa Fe Klan Official  Santa Fe Klan Official            Мексика
# 999      Anupam Movie Songs      Anupam Movie Songs          Бангладеш
#
#       Подписчики   Просмотры      Лайки  Комментарии  Категория контента  \
# 0    229500000.0    103800.0     2800.0        158.0      Музыка и Танцы
# 3    117000000.0  68500000.0  2900000.0      99900.0   Компьютерные игры
# 4    111600000.0   1400000.0   110700.0       7800.0            Анимация
# 7     91800000.0    144900.0     5100.0        207.0   Компьютерные игры
# 9     89700000.0     89600.0     2400.0         91.0      Музыка и Танцы
# ..           ...         ...        ...          ...                 ...
# 984   10200000.0     21200.0      652.0         15.0         Образование
# 989   10100000.0     11800.0     1200.0         72.0  Новости и Политика
# 991   10100000.0     98400.0     4000.0        884.0  Новости и Политика
# 992   10100000.0         0.0        0.0          0.0      Музыка и Танцы
# 999   10100000.0     41200.0      315.0         18.0      Музыка и Танцы
#
#             Ранг
# 0    Мега (>50M)
# 3    Мега (>50M)
# 4    Мега (>50M)
# 7    Мега (>50M)
# 9    Мега (>50M)
# ..           ...
# 984  Нано (<15M)
# 989  Нано (<15M)
# 991  Нано (<15M)
# 992  Нано (<15M)
# 999  Нано (<15M)
#
# [578 rows x 9 columns]

# %% [markdown]
# Сделаем новую колонку с метрикой "Вовлеченность подписчиков", запишем туда сумму просмотров, комментариев и лайков.

# %%
df_youtube['Вовлеченность подписчиков'] = df_youtube['Просмотры'] + df_youtube['Комментарии'] + df_youtube['Лайки']
df_youtube
# Out:
#             Название канала             Ник YouTube Основная аудитория  \
# 0                  T-Series                 tseries              Индия
# 3                   MrBeast                 MrBeast                США
# 4                 PewDiePie               PewDiePie                США
# 7                       WWE            WWEFanNation                США
# 9         Zee Music Company         zeemusiccompany              Индия
# ..                      ...                     ...                ...
# 984          Roshan Zindagi          Roshan Zindagi              Индия
# 989    Sab Kuchh Sekho Jano       Sabkuchhsikhojano              Индия
# 991                Fox News          FoxNewsChannel                США
# 992  Santa Fe Klan Official  Santa Fe Klan Official            Мексика
# 999      Anupam Movie Songs      Anupam Movie Songs          Бангладеш
#
#       Подписчики   Просмотры      Лайки  Комментарии  Категория контента  \
# 0    229500000.0    103800.0     2800.0        158.0      Музыка и Танцы
# 3    117000000.0  68500000.0  2900000.0      99900.0   Компьютерные игры
# 4    111600000.0   1400000.0   110700.0       7800.0            Анимация
# 7     91800000.0    144900.0     5100.0        207.0   Компьютерные игры
# 9     89700000.0     89600.0     2400.0         91.0      Музыка и Танцы
# ..           ...         ...        ...          ...                 ...
# 984   10200000.0     21200.0      652.0         15.0         Образование
# 989   10100000.0     11800.0     1200.0         72.0  Новости и Политика
# 991   10100000.0     98400.0     4000.0        884.0  Новости и Политика
# 992   10100000.0         0.0        0.0          0.0      Музыка и Танцы
# 999   10100000.0     41200.0      315.0         18.0      Музыка и Танцы
#
#             Ранг  Вовлеченность подписчиков
# 0    Мега (>50M)                   106758.0
# 3    Мега (>50M)                 71499900.0
# 4    Мега (>50M)                  1518500.0
# 7    Мега (>50M)                   150207.0
# 9    Мега (>50M)                    92091.0
# ..           ...                        ...
# 984  Нано (<15M)                    21867.0
# 989  Нано (<15M)                    13072.0
# 991  Нано (<15M)                   103284.0
# 992  Нано (<15M)                        0.0
# 999  Нано (<15M)                    41533.0
#
# [578 rows x 10 columns]

# %%
#df_youtube.to_excel('data/df_youtube.xlsx', index=False)
